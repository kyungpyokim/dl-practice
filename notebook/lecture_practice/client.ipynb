# %%
import requests

url = 'http://localhost:8000/infer'

with open('../../data/images/마동석/Image_1.jpg', 'rb') as f:
    res = requests.post(url, files={'file': f})

res
# Out:
# <Response [200]>

# %%
res.json()
# Out:
# {'result': '마동석',
#  'index': 0,
#  'filename': 'd45ac165-517f-4118-9f36-9b86b00979dd.jpg'}
