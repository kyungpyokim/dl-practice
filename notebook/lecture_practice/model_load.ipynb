# %%
import torch
import torch.nn as nn

from lib.path import model_file_path


class Lenet(nn.Module):
    def __init__(self):
        super.__init__()

    def forward(self, x):
        return x


model = torch.load(model_file_path('lenet_model.pth'), weights_only=False)

# %%
model
